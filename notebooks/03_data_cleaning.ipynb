# %% [markdown]
# # 03: Data Cleaning
#
# This notebook prepares the merged UNSW-NB15 dataset for exploratory analysis and modelling by removing noise, correcting inconsistencies, and filling missing values.
#
# The cleaning steps applied are: dropping redundant and identifier columns that would cause the model to learn deployment-specific properties rather than traffic behaviour; stripping leading and trailing whitespace from column names and string values; normalising inconsistent attack category names; filling missing values in known columns with appropriate defaults; removing duplicate records; and removing impossible records where a connection has zero duration and no bytes transferred. The expected output is a cleaned dataset at `data/cleaned/UNSW-NB15.csv`, ready for exploratory data analysis in notebook 04.

# %% [markdown]
# ## 3.1: Import Libraries
#
# This section imports all libraries required by the notebook and configures global display settings. Only pandas is needed for this notebook as all operations involve loading, transforming, and exporting tabular data. The display option prevents pandas from truncating long column values in any intermediate outputs.

# %%
import os
import pandas as pd

# Prevent truncation of long column values in displayed DataFrames.
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 3.2: Load Dataset
#
# This section loads the merged dataset produced by notebook 01 from `data/processed/UNSW-NB15.csv`. The `'-'` character is treated as a missing value to be consistent with how the raw files were loaded in the merging step.

# %%
# Load the merged dataset. '-' values are treated as missing to remain consistent with the raw data loading.
df = pd.read_csv('../data/processed/UNSW-NB15.csv', na_values=['-'], low_memory=False)

# %% [markdown]
# ## 3.3: Remove Redundant Features
#
# This section drops columns that would either leak environment-specific information into the model or are mathematically redundant with other features. IP addresses and port numbers identify the specific machines and services involved in a connection, not the nature of the traffic itself — including them would cause the model to memorise the lab network topology rather than learn transferable attack patterns. Timestamps similarly encode when a capture occurred rather than how traffic behaves. The `tcprtt` column is the arithmetic sum of `synack` and `ackdat` and therefore carries no additional information. The TCP sequence base values `stcpb` and `dtcpb` are randomly initialised by the operating system and have no predictive value.

# %%
# Define the list of columns to drop and remove them from the DataFrame.
features_to_drop = [
    'srcip',  # Identifier: source IP encodes network topology, not traffic behaviour.
    'dstip',  # Identifier: destination IP encodes network topology, not traffic behaviour.
    'sport',  # Identifier: source port is randomly assigned by the operating system.
    'dsport',  # Redundant: 'service' already captures protocol-level destination port meaning.
    'Stime',  # Temporal: encodes when the capture occurred, not how the traffic behaves.
    'Ltime',  # Temporal: encodes when the capture occurred, not how the traffic behaves.
    'tcprtt',  # Redundant: equals synack + ackdat and provides no additional information.
    'stcpb',  # Random: TCP sequence numbers are randomly initialised by the operating system.
    'dtcpb',  # Random: TCP sequence numbers are randomly initialised by the operating system.
]
df.drop(columns=features_to_drop, inplace=True)

# %% [markdown]
# ## 3.4: Strip Whitespace
#
# This section removes leading and trailing whitespace from all column names and from all string-typed feature values. Whitespace in column names can silently break code that references columns by name. Whitespace in categorical values such as `attack_cat` or `service` would cause the same category to appear as multiple distinct values — for example, `' Exploits'` and `'Exploits'` — which would inflate cardinality and produce incorrect class distributions and encodings in downstream steps.

# %%
# Strip leading and trailing whitespace from all column header names.
df.columns = df.columns.str.strip()

# Strip leading and trailing whitespace from all string-typed feature values.
string_columns = df.select_dtypes(include=['object', 'string']).columns
df[string_columns] = df[string_columns].apply(lambda x: x.str.strip())

# %%
# Verify that whitespace has been removed from the 'attack_cat' column value counts.
df['attack_cat'].value_counts()

# %% [markdown]
# ## 3.5: Normalise Attack Category Names
#
# The raw dataset contains two distinct string values for the same attack type: `Backdoor` and `Backdoors`. These are not two separate categories — they represent the same attack with inconsistent naming in the source data. Treating them as separate classes would cause the multi-class classifier in notebook 07 to split predicted probability between two functionally identical targets, artificially suppressing recall and F1 for both.
#
# This section normalises `Backdoors` → `Backdoor` before missing values are filled, so the correction propagates cleanly through the rest of the pipeline. After this step the dataset should contain exactly one `Backdoor` category.

# %%
# Normalise 'Backdoors' to 'Backdoor' — both refer to the same attack type.
df['attack_cat'] = df['attack_cat'].replace('Backdoors', 'Backdoor')

# Confirm the normalisation — 'Backdoors' should no longer appear.
print("Attack category counts after normalisation:")
print(df['attack_cat'].value_counts())
# Out:
# Attack category counts after normalisation:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            2329
# Shellcode           1511
# Worms                174
# Name: count, dtype: int64

# %% [markdown]
# ## 3.6: Handle Missing Values
#
# This section identifies which columns still contain missing values after the whitespace stripping step and resolves them with semantically appropriate fill values. The strategy used for each column depends on its meaning: categorical columns with no recorded value are filled with a label that indicates absence, while numeric columns that count protocol events are filled with zero to represent that no such event occurred. Inspecting which columns have missing values before applying any fixes avoids blanket strategies that may be incorrect for certain features.

# %%
# Display only the columns that still contain at least one missing value.
missing_values = df.isna().sum()
missing_values[missing_values > 0]

# %% [markdown]
# ### 3.6.1: Handle Missing Values in the `service` Column
#
# The `service` column contains the application-layer protocol inferred from the connection (e.g., `http`, `ftp`, `dns`). A missing value means the protocol could not be identified — this is a meaningful state and is filled with the label `'unidentified'` rather than dropping the record or imputing a guess. The value counts are printed before and after to confirm the fill was applied correctly.

# %%
print("=== service: Value Counts Before Fill ===")
print(df['service'].value_counts())

# Fill missing values in 'service' with 'unidentified' to represent connections where the protocol could not be determined.
df['service'] = df['service'].fillna('unidentified')

print("\n=== service: Value Counts After Fill ===")
print(df['service'].value_counts())

# %% [markdown]
# ### 3.6.2: Handle Missing Values in the `ct_flw_http_mthd` Column
#
# The `ct_flw_http_mthd` column counts the number of HTTP methods (GET, POST, etc.) observed in a connection window. A missing value indicates that no HTTP methods were recorded — likely because the connection did not use HTTP. This is filled with `0.0` to represent the absence of any HTTP method counts.

# %%
print("=== ct_flw_http_mthd: Value Counts Before Fill ===")
print(df['ct_flw_http_mthd'].value_counts())

# Fill missing values in 'ct_flw_http_mthd' with 0 to represent connections with no HTTP method activity.
df['ct_flw_http_mthd'] = df['ct_flw_http_mthd'].fillna(0.0)

print("\n=== ct_flw_http_mthd: Value Counts After Fill ===")
print(df['ct_flw_http_mthd'].value_counts())

# %% [markdown]
# ### 3.6.3: Handle Missing Values in the `is_ftp_login` Column
#
# The `is_ftp_login` column is a binary flag indicating whether an FTP session included a login. A missing value indicates that the connection did not involve FTP at all, which is semantically equivalent to no login occurring. This is filled with `0.0`.

# %%
print("=== is_ftp_login: Value Counts Before Fill ===")
print(df['is_ftp_login'].value_counts())

# Fill missing values in 'is_ftp_login' with 0 to represent connections with no FTP login activity.
df['is_ftp_login'] = df['is_ftp_login'].fillna(0.0)

print("\n=== is_ftp_login: Value Counts After Fill ===")
print(df['is_ftp_login'].value_counts())

# %% [markdown]
# ### 3.6.4: Handle Missing Values in the `attack_cat` Column
#
# The `attack_cat` column identifies the specific attack type for each record. Records with a binary `Label` value of `0` are normal traffic and have no attack category — these missing values represent normal connections and are filled with the label `'Normal'`. The binary label distribution is printed first to confirm that all records with missing `attack_cat` are indeed labelled as normal before the fill is applied.

# %%
print("=== Label: Value Counts ===")
print(df['Label'].value_counts())

print("\n=== attack_cat: Value Counts Before Fill ===")
print(df['attack_cat'].value_counts())

# Fill missing 'attack_cat' values with 'Normal' — missing entries correspond to normal traffic (Label = 0).
df['attack_cat'] = df['attack_cat'].fillna('Normal')

print("\n=== attack_cat: Value Counts After Fill ===")
print(df['attack_cat'].value_counts())

# %% [markdown]
# ## 3.7: Remove Duplicates
#
# This section removes exact duplicate rows from the dataset. Duplicate records can arise from overlapping capture windows in the raw data collection process. Keeping duplicates would artificially inflate the frequency of certain traffic patterns during training, potentially biasing the model toward memorising repeated examples rather than generalising from the full data distribution.

# %%
# Remove exact duplicate rows in place.
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 3.8: Remove Impossible Records
#
# This section removes records that represent physically impossible network connections. A connection with a duration of exactly zero and no bytes transferred in either direction cannot represent real traffic — it is either a logging artefact or a corrupted entry. Retaining such records would introduce noise with no signal and could distort the distributions of duration and byte-count features.

# %%
# Remove records where duration is zero and no bytes were transferred in either direction.
df = df[~(df['dur'] == 0) & ((df['sbytes'] > 0) | (df['dbytes'] > 0))]

# %% [markdown]
# ## 3.9: Cleaned Dataset Shape
#
# This section reports the final record count and feature count after all cleaning steps have been applied. The expected output is approximately 2 million records across 40 features. Comparing this against the profiling results from notebook 02 confirms that the intended records and columns were removed without unintended data loss.

# %%
# Report the final record count and feature count after all cleaning steps.
cleaned_number_of_records = df.shape[0]
cleaned_number_of_features = df.shape[1]
print(f"Number of records: {cleaned_number_of_records:,}")
print(f"Number of features: {cleaned_number_of_features}")

# %% [markdown]
# ## 3.10: Export Cleaned Dataset
#
# This section writes the cleaned DataFrame to a CSV file at `data/cleaned/UNSW-NB15.csv`. This file is the input for exploratory data analysis in notebook 04 and all subsequent notebooks in the pipeline. The index is excluded from the output to avoid introducing a spurious index column during downstream loads.

# %%
# Create the output directory if it does not already exist.
os.makedirs('../data/cleaned', exist_ok=True)

# Export the cleaned DataFrame to CSV. The index is excluded to avoid a spurious index column on reload.
df.to_csv('../data/cleaned/UNSW-NB15.csv', index=False)
