# %% [markdown]
# # 03: Perform Data Cleaning
# This notebook strips whitespace, drops redundant features, handles missing values, removes duplicates and impossible records.

# %% [markdown]
# ## 3.1: Import Library

# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## 3.2: Load CSV File

# %%
df = pd.read_csv('../data/processed/UNSW-NB15.csv', low_memory=False)

# %% [markdown]
# ## 3.3: Remove Redundant Features

# %%
features_to_drop = [
    'srcip',
    'dstip',
    'sport',
    'dsport', #
    'Stime',
    'Ltime',
    'tcprtt',
    'stcpb',
    'dtcpb'
]

# %% [markdown]
# ## 3.4: Strip Whitespace

# %%
# Strip whitespace in column headers
df.columns = df.columns.str.strip()
# Strip whitespace in string features
columns = df.select_dtypes(include=['object', 'string']).columns
df[columns] = df[columns].apply(lambda x: x.str.strip())

# %%
# Check if whitespace in 'attack_cat' column has been removed
df["attack_cat"].value_counts()
# Out:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            1795
# Shellcode           1511
# Backdoors            534
# Worms                174
# Name: count, dtype: int64

# %%
df.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0   1390  149.171.126.6     53   udp   CON  0.001055     132
# 1  59.166.0.0  33661  149.171.126.9   1024   udp   CON  0.036133     528
# 2  59.166.0.6   1464  149.171.126.7     53   udp   CON  0.001119     146
# 3  59.166.0.5   3593  149.171.126.5     53   udp   CON  0.001209     132
# 4  59.166.0.3  49664  149.171.126.0     53   udp   CON  0.001169     146
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     164    31  ...           0           3           7          1
# 1     304    31  ...           0           2           4          2
# 2     178    31  ...           0          12           8          1
# 3     164    31  ...           0           6           9          1
# 4     178    31  ...           0           7           9          1
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            3                 1                 1               1
# 1            3                 1                 1               2
# 2            2                 2                 1               1
# 3            1                 1                 1               1
# 4            1                 1                 1               1
#
#    attack_cat  Label
# 0         NaN      0
# 1         NaN      0
# 2         NaN      0
# 3         NaN      0
# 4         NaN      0
#
# [5 rows x 49 columns]
