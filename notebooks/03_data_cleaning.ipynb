# %% [markdown]
# # 03: Perform Data Cleaning
# This notebook drops redundant features, strips whitespace, handles missing values, removes duplicates and impossible records.

# %% [markdown]
# ## 3.1: Import Library

# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## 3.2: Load CSV File

# %%
df = pd.read_csv('../data/processed/UNSW-NB15.csv', na_values=['-'], low_memory=False)

# %% [markdown]
# ## 3.3: Remove Redundant Features

# %%
features_to_drop = [
    'srcip',  # Makes model learn environment not behaviour
    'dstip',  # Makes model learn environment not behaviour
    'sport',  # Randomly assigned by OS
    'dsport', # 'service' already captures protocol-level destination port meaning in a cleaner categorical form
    'Stime',  # Makes model learn environment not behaviour
    'Ltime',  # Makes model learn environment not behaviour
    'tcprtt', # Sum of 'synack' + 'ackdat' (does not provide information)
    'stcpb',  # TCP sequence numbers are randomly initialised
    'dtcpb'   # TCP sequence numbers are randomly initialised
]
df.drop(columns=features_to_drop, inplace=True)

# %% [markdown]
# ## 3.4: Strip Whitespace

# %%
# Strip whitespace in column headers
df.columns = df.columns.str.strip()
# Strip whitespace in string features
columns = df.select_dtypes(include=['object', 'string']).columns
df[columns] = df[columns].apply(lambda x: x.str.strip())

# %%
# Check if whitespace in 'attack_cat' column has been removed
df["attack_cat"].value_counts()
# Out:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            1795
# Shellcode           1511
# Backdoors            534
# Worms                174
# Name: count, dtype: int64

# %% [markdown]
# ## 3.5: Handle Missing Values

# %%
# Check which features contain missing values
missing_values = df.isna().sum()
missing_values[missing_values > 0]
# Out:
# service             1246397
# ct_flw_http_mthd    1348145
# is_ftp_login        1429879
# attack_cat          2218764
# dtype: int64

# %%
df[df["is_ftp_login"].isnull() & (df["service"] != 'ftp')]
# Out:
#         proto state       dur  sbytes  dbytes  sttl  dttl  sloss  dloss  \
# 1087203   tcp   FIN  0.121478     258     172   252   254      0      0
# 1087204   tcp   FIN  0.649902     734   42014    62   252      2     17
# 1087205   tcp   FIN  1.623129     364   13186    62   252      1      6
# 1087207   tcp   FIN  0.449454     534     268   254   252      2      1
# 1087208   tcp   FIN  0.380537     534     268   254   252      2      1
# ...       ...   ...       ...     ...     ...   ...   ...    ...    ...
# 2540039   tcp   CON  0.564998   14106  772406    31    29      2    262
# 2540041   tcp   CON  0.564998   14106  772406    31    29      2    262
# 2540042   tcp   FIN  0.087306     320    1828    31    29      1      2
# 2540045   tcp   CON  2.200934    3498  166054    31    29      2     57
# 2540046   tcp   CON  0.942984     574     676    62   252      5      6
#
#           service  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_dst_ltm  \
# 1087203       NaN  ...                       1           1           1
# 1087204       NaN  ...                      43           6           1
# 1087205       NaN  ...                       7           6           2
# 1087207       NaN  ...                      43          39           2
# 1087208       NaN  ...                      43          39           2
# ...           ...  ...         ...         ...         ...         ...
# 2540039      http  ...                       1           1           4
# 2540041       NaN  ...                       2           1           4
# 2540042  ftp-data  ...                       1           2           3
# 2540045      http  ...                       1           1           2
# 2540046      pop3  ...                       1           1           2
#
#          ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 1087203            1                 1                 1               1
# 1087204            1                 1                 1               2
# 1087205            2                 1                 1               3
# 1087207            2                 2                 1              40
# 1087208            2                 2                 1              40
# ...              ...               ...               ...             ...
# 2540039            2                 2                 2               2
# 2540041            2                 2                 2               2
# 2540042            3                 1                 1               3
# 2540045            4                 2                 2               2
# 2540046            4                 2                 2               2
#
#          attack_cat  Label
# 1087203         NaN      0
# 1087204         NaN      0
# 1087205         NaN      0
# 1087207         NaN      0
# 1087208         NaN      0
# ...             ...    ...
# 2540039         NaN      0
# 2540041         NaN      0
# 2540042         NaN      0
# 2540045         NaN      0
# 2540046    Exploits      1
#
# [1428612 rows x 40 columns]

# %%
df['service'].value_counts()
# Out:
# service
# dns         781668
# http        206273
# ftp-data    125783
# smtp         81645
# ftp          49090
# ssh          47160
# pop3          1533
# dhcp           172
# ssl            142
# snmp           113
# radius          40
# irc             31
# Name: count, dtype: int64
