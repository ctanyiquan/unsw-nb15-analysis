# %% [markdown]
# # 03: Perform Data Cleaning
# This notebook drops redundant features, strips whitespace, handles missing values, removes duplicates and impossible records.

# %% [markdown]
# ## 3.1: Import Library

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 3.2: Load CSV File

# %%
df = pd.read_csv('../data/processed/UNSW-NB15.csv', na_values=['-'], low_memory=False)

# %% [markdown]
# ## 3.3: Remove Redundant Features

# %%
features_to_drop = [
    'srcip',  # Makes model learn environment not behaviour
    'dstip',  # Makes model learn environment not behaviour
    'sport',  # Randomly assigned by OS
    'dsport', # 'service' already captures protocol-level destination port meaning in a cleaner categorical form
    'Stime',  # Makes model learn environment not behaviour
    'Ltime',  # Makes model learn environment not behaviour
    'tcprtt', # Sum of 'synack' + 'ackdat' (does not provide information)
    'stcpb',  # TCP sequence numbers are randomly initialised
    'dtcpb'   # TCP sequence numbers are randomly initialised
]
df.drop(columns=features_to_drop, inplace=True)

# %% [markdown]
# ## 3.4: Strip Whitespace

# %%
# Strip whitespace in column headers
df.columns = df.columns.str.strip()
# Strip whitespace in string features
columns = df.select_dtypes(include=['object', 'string']).columns
df[columns] = df[columns].apply(lambda x: x.str.strip())

# %%
# Check if whitespace in 'attack_cat' column has been removed
df['attack_cat'].value_counts()
# Out:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            1795
# Shellcode           1511
# Backdoors            534
# Worms                174
# Name: count, dtype: int64

# %% [markdown]
# ## 3.5: Normalise Attack Category Names
#
# The raw dataset contains two distinct string values for the same attack type: `Backdoor` and `Backdoors`. These are not two separate categories — they represent the same attack with inconsistent naming in the source data. Treating them as separate classes would cause the multi-class classifier in notebook 07 to split predicted probability between two functionally identical targets, artificially suppressing recall and F1 for both.
#
# This section normalises `Backdoors` → `Backdoor` before missing values are filled, so the correction propagates cleanly through the rest of the pipeline. After this step the dataset should contain exactly one `Backdoor` category.

# %%
# Normalise 'Backdoors' to 'Backdoor' — both refer to the same attack type.
df['attack_cat'] = df['attack_cat'].replace('Backdoors', 'Backdoor')

# Confirm the normalisation — 'Backdoors' should no longer appear.
print("Attack category counts after normalisation:")
print(df['attack_cat'].value_counts())
# Out:
# Attack category counts after normalisation:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            2329
# Shellcode           1511
# Worms                174
# Name: count, dtype: int64

# %% [markdown]
# ## 3.6: Handle Missing Values

# %%
# Check which features contain missing values
missing_values = df.isna().sum()
missing_values[missing_values > 0]
# Out:
# service             1246397
# ct_flw_http_mthd    1348145
# is_ftp_login        1429879
# attack_cat          2218764
# dtype: int64

# %% [markdown]
# ### 3.6.1: Handle Missing Values in 'service' Column

# %%
print(f'Before:\n{df['service'].value_counts()}')

print('\nFilling missing values...\n')
df['service'] = df['service'].fillna('unidentified')

print(f'After:\n{df['service'].value_counts()}')
# Out:
# Before:
# service
# dns         781668
# http        206273
# ftp-data    125783
# smtp         81645
# ftp          49090
# ssh          47160
# pop3          1533
# dhcp           172
# ssl            142
# snmp           113
# radius          40
# irc             31
# Name: count, dtype: int64
#
# Filling missing values...
#
# After:
# service
# unidentified    1246397
# dns              781668
# http             206273
# ftp-data         125783
# smtp              81645
# ftp               49090
# ssh               47160
# pop3               1533
# dhcp                172
# ssl                 142
# snmp                113
# radius               40
# irc                  31
# Name: count, dtype: int64

# %% [markdown]
# ### 3.6.2: Handle Missing Values in 'ct_flw_http_mthd' Column

# %%
print(f'Before:\n{df['ct_flw_http_mthd'].value_counts()}')

print('\nFilling missing values...\n')
df['ct_flw_http_mthd'] = df['ct_flw_http_mthd'].fillna(0.0)

print(f'After:\n{df['ct_flw_http_mthd'].value_counts()}')
# Out:
# Before:
# ct_flw_http_mthd
# 0.0     986791
# 1.0     188008
# 6.0       7902
# 4.0       6564
# 3.0        738
# 2.0        588
# 5.0        430
# 9.0        270
# 14.0       224
# 12.0       132
# 30.0        60
# 8.0         56
# 16.0        48
# 36.0        36
# 10.0        30
# 25.0        25
# Name: count, dtype: int64
#
# Filling missing values...
#
# After:
# ct_flw_http_mthd
# 0.0     2334936
# 1.0      188008
# 6.0        7902
# 4.0        6564
# 3.0         738
# 2.0         588
# 5.0         430
# 9.0         270
# 14.0        224
# 12.0        132
# 30.0         60
# 8.0          56
# 16.0         48
# 36.0         36
# 10.0         30
# 25.0         25
# Name: count, dtype: int64

# %% [markdown]
# ### 3.6.3: Handle Missing Values in 'is_ftp_login' Column

# %%
print(f'Before:\n{df['is_ftp_login'].value_counts()}')

print('\nFilling missing values...\n')
df['is_ftp_login'] = df['is_ftp_login'].fillna(0.0)

print(f'After:\n{df['is_ftp_login'].value_counts()}')
# Out:
# Before:
# is_ftp_login
# 0.0    1066593
# 1.0      43389
# 4.0        156
# 2.0         30
# Name: count, dtype: int64
#
# Filling missing values...
#
# After:
# is_ftp_login
# 0.0    2496472
# 1.0      43389
# 4.0        156
# 2.0         30
# Name: count, dtype: int64

# %% [markdown]
# ### 3.6.4: Handle Missing Values in 'attack_cat' Column

# %%
print(df['Label'].value_counts())

print(f'\nBefore:\n{df['attack_cat'].value_counts()}')

print('\nFilling missing values...\n')
df['attack_cat'] = df['attack_cat'].fillna('Normal')

print(f'After:\n{df['attack_cat'].value_counts()}')
# Out:
# Label
# 0    2218764
# 1     321283
# Name: count, dtype: int64
#
# Before:
# attack_cat
# Generic           215481
# Exploits           44525
# Fuzzers            24246
# DoS                16353
# Reconnaissance     13987
# Analysis            2677
# Backdoor            2329
# Shellcode           1511
# Worms                174
# Name: count, dtype: int64
#
# Filling missing values...
#
# After:
# attack_cat
# Normal            2218764
# Generic            215481
# Exploits            44525
# Fuzzers             24246
# DoS                 16353
# Reconnaissance      13987
# Analysis             2677
# Backdoor             2329
# Shellcode            1511
# Worms                 174
# Name: count, dtype: int64

# %% [markdown]
# ## 3.7: Remove Duplicates

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 3.8: Remove Impossible Records

# %%
df = df[~(df['dur'] == 0) & ((df['sbytes'] > 0) | (df['dbytes'] > 0))]

# %% [markdown]
# ## 3.9: New Shape

# %%
new_number_of_records = df.shape[0]
new_number_of_features = df.shape[1]
print(f"Number of records: {new_number_of_records:,}")
print(f"Number of features: {new_number_of_features}")
# Out:
# Number of records: 2,024,469
# Number of features: 40

# %% [markdown]
# ## 3.10: Export CSV File

# %%
df.to_csv('../data/cleaned/UNSW-NB15.csv', index=False)
